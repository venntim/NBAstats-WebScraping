# %%
import pandas as pd
import numpy as np
from requests import get
from bs4 import BeautifulSoup
from time import sleep
from random import randint

# %%
from NBAstats import StatsNBA

# %%
cavs = StatsNBA("CLE", 1971, 2023)

# %%
cavs.columns
# Out:
# ['G',
#  'Date',
#  'Start (ET)',
#  '#',
#  '##',
#  'Out Home',
#  'Opponent',
#  'W\\L',
#  'OT',
#  'Tm',
#  'Opp',
#  'W',
#  'L',
#  'Streak',
#  'Notes']

# %%
cavs.get_stats()
# Out:
#     G               Date Start (ET) Out Home                Opponent W\L OT  \
# 0   1  Wed, Oct 14, 1970        NaN        @          Buffalo Braves   L
# 0   2  Fri, Oct 16, 1970        NaN        @  Portland Trail Blazers   L
# 0   3  Sat, Oct 17, 1970        NaN        @  San Francisco Warriors   L
# 0   4  Tue, Oct 20, 1970        NaN        @  Portland Trail Blazers   L
# 0   5  Thu, Oct 22, 1970        NaN        @       San Diego Rockets   L
# .. ..                ...        ...      ...                     ...  .. ..
# 0   1  Sat, Apr 15, 2023      6:00p                  New York Knicks   L
# 0   2  Tue, Apr 18, 2023      7:30p                  New York Knicks   W
# 0   3  Fri, Apr 21, 2023      8:30p        @         New York Knicks   L
# 0   4  Sun, Apr 23, 2023      1:00p        @         New York Knicks   L
# 0   5  Wed, Apr 26, 2023      7:00p                  New York Knicks   L
#
#      Tm  Opp  W  L Streak
# 0    92  107  0  1    L 1
# 0   112  115  0  2    L 2
# 0   108  128  0  3    L 3
# 0    98  120  0  4    L 4
# 0   110  140  0  5    L 5
# ..  ...  ... .. ..    ...
# 0    97  101  0  1    L 1
# 0   107   90  1  1    W 1
# 0    79   99  1  2    L 1
# 0    93  102  1  3    L 2
# 0    95  106  1  4    L 3
#
# [4507 rows x 12 columns]
